# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Tasks:
#
# #1 Determine the five most common journals and the total articles for each. (Clean: rename all entries of each journal to same title)
#
# #2 Calculate the mean, median, and standard deviation of the open-access cost per article for each journal. (Clean: remove '£' & '$' symbols)
#
# #### Answers found in tables below:

# %%
#table for #1
group_array = np.array([[406],[278],[212],[167],[95]])
df_journals = pd.DataFrame(group_array)

#labeling
df_journals.index = ['Elsevier','Public Library of Science','John Wiley & Sons',
                     'Directors vs Stars', 'BioMed Central']
df_journals.columns = ['Total Articles']
df_journals
# Out:
#                            Total Articles
# Elsevier                              406
# Public Library of Science             278
# John Wiley & Sons                     212
# Directors vs Stars                    167
# BioMed Central                         95

# %%
#table for #2
group_array2 = np.array([[26886, 2355, 154440],[55724, 1040, 26209],[21645, 1975, 136351],[19775, 2040, 132975],[22364, 1315, 144128]])
df_groups = pd.DataFrame(group_array2)

#labeling
df_groups.index = ['Elsevier','Public Library of Science','John Wiley & Sons',
                     'Directors vs Stars', 'BioMed Central']
df_groups.columns = ['Mean','Median','Std']
df_groups
# Out:
#                             Mean  Median     Std
# Elsevier                   26886    2355  154440
# Public Library of Science  55724    1040   26209
# John Wiley & Sons          21645    1975  136351
# Directors vs Stars         19775    2040  132975
# BioMed Central             22364    1315  144128

# %%
df = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv',encoding ='latin1')

# %%
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
pd.options.display.max_rows = 2300
print(df)
# Out:
#                                              PMID/PMCID  \
# 0                                                   NaN
# 1                                            PMC3679557
# 2                                 23043264  PMC3506128
# 3                                   23438330 PMC3646402
# 4                                  23438216 PMC3601604
# 5                                            PMC3579457
# 6                                            PMC3709265
# 7                                  23057412 PMC3495574
# 8                                     PMCID: PMC3780468
# 9                                     PMCID: PMC3621575
# 10                                    PMCID: PMC3739413
# 11                                    PMCID: PMC3530961
# 12                                    PMCID: PMC3624797
# 13                                           PMC3413243
# 14                                           PMC3694353
# 15                                           PMC3572711
# ...

# %%
#rename journal title column and uppercase all publisher/journal title names

df = df.rename(columns={'Journal title':'Journal Title'})
df['Journal Title'] = df['Journal Title'].str.upper()
df['Journal Title'] = df['Journal Title'].str.strip()
df['Publisher'] = df['Publisher'].str.upper()
df['Publisher'] = df['Publisher'].str.strip()

# %%
#remove all £ and $ signs from cost column

df = df.replace('£','',regex=True)
df = df.replace('\$','',regex=True)

# %%
#rename cost column & convert to integers

df = df.rename(columns={'COST (£) charged to Wellcome (inc VAT when charged)': 'Cost'})
df['Cost'] = df['Cost'].apply(float)

# %%
#match all publisher names (A-E)

df = df.replace('ACS (AMERCIAN CHEMICAL SOCIETY) PUBLICATIONS','ACS')
df = df.replace('ACS PUBLICATIONS','ACS')
df = df.replace('AMERICAN CHEMICAL SOCIETY','ACS')
df = df.replace('AMERICAN CHEMICAL SOCIETY PUBLICATIONS','ACS')
df = df.replace('AMERICAN PSYCHIATRIC PUBLISHING','AMERICAN PSYCHIATRIC ASSOCIATION')
df = df.replace('AMERICAN SOC FOR BIOCHEMISTRY AND MOLECULAR BIOLOGY','ASBMB')
df = df.replace('AMERICAN SOCIETY FOR BIOCHEMISTRY AND MOLECULAR BIOLGY','ASBMB')
df = df.replace('AMERICAN SOCIETY FOR BIOCHEMISTRY AND MOLECULAR BIOLOGY','ASBMB')
df = df.replace('AMERICAN SOCIETY OF HAEMATOLOGY','AMERICAN SOCIETY OF HEMATOLOGY')
df = df.replace('AMERICAN SOCIETY OF HAMATOLOGY','AMERICAN SOCIETY OF HEMATOLOGY')
df = df.replace('AMERICAN SOCIETY OF MICROBIOLOGY','ASM')
df = df.replace('AMERICAN SOCIETY FOR MICROBIOLOGY','ASM')
df = df.replace('AMBSB','ASBMB')
df = df.replace('ASBMB CADMUS','ASBMB')
df = df.replace('ASBMB/CADMUS','ASBMB')
df = df.replace('ASBMB/CENVEO PUBLISHER SERVICES','ASBMB')
df = df.replace('ASBMC /CENVEO','ASBMB')
df = df.replace('ASM (AMERICAN SOCIETY FOR MICROBIOLOGY)','ASM')
df = df.replace('BENTHAN SCIENCE PUBLISHERS','BENTHAM SCIENCE PUBLISHERS')
df = df.replace('BIOMED CENTRAL LIMITED','BMC')
df = df.replace('BIOMED CENTRAL LTD','BMC')
df = df.replace('BIOMED CENTRAL','BMC')
df = df.replace('BMJ GROUP','BMJ')
df = df.replace('BMJ JOURNALS','BMJ')
df = df.replace('BMJ PUBLISHING GROUP','BMJ')
df = df.replace('BMJ PUBLISHING GROUP LTD','BMJ')
df = df.replace('BMJ PUBLISHING GROUP LTD & BRITISH THORACIC SOCIETY','BMJ')
df = df.replace('BRITISH MEDICAL JOURNAL','BMJ')
df = df.replace('CADMUS JOURNAL SERVICE','CADMUS')
df = df.replace('CADMUS JOURNAL SERVICES','CADMUS')
df = df.replace('CENVEO PUBLISHER SERVICES/ASM JV1','CENVEO PUBLISHER SERVICES')
df = df.replace('CAMBRIDGE UNIVERSITY PRESS','CUP')
df = df.replace('CAMBRIDGE JOURNALS','CUP')
df = df.replace('CAMBRIDGE UNI PRESS','CUP')
df = df.replace('CAMBRIDGE UNIV PRESS','CUP')
df = df.replace('CAMDUS JOURNAL SERVICES','CADMUS')
df = df.replace('COLD SPRING HABOUR PRESS','COLD SPRING HARBOR')
df = df.replace('COLD SPRING HARBOR LABORATORY PRESS','COLD SPRING HARBOR')
df = df.replace('COLD SPRING HARBOR PRESS','COLD SPRING HARBOR')
df = df.replace('COLD SPRING HARBOR PUBLICATIONS','COLD SPRING HARBOR')
df = df.replace('COMPANY OF BIOLOGIST','COMPANY OF BIOLOGISTS')
df = df.replace('COMPANY OF BIOLOGISTS LTD','COMPANY OF BIOLOGISTS')
df = df.replace('DARMOUTH JOURNAL SERVICES','DARTMOUTH JOURNAL SERVICES')
df = df.replace('DARTMOUTH JOURNALS','DARTMOUTH JOURNAL SERVICES')
df = df.replace('ELSEVEIER SCIENCE','ELSEVIER')
df = df.replace('ELSEVIER (CELL PRESS)','ELSEVIER')
df = df.replace('ELSEVIER / CELL SCIENCE','ELSEVIER')
df = df.replace('ELSEVIER LTD','ELSEVIER')
df = df.replace('ELSEVIER B.V.','ELSEVIER')
df = df.replace('ELSEVIER/CELL PRESS','ELSEVIER')

# %%
#match all publisher names (F-R)

df = df.replace('FEDERATION OF AMERICAN SOCIETIES FOR EXPERIMENTAL BIOLOGY','FASEB')
df = df.replace('FEDERATION OF AMERICAN SOCIETIES FOR EXPERIMENTAL BIOLOGY (FASEB)','FASEB')
df = df.replace('FEDERATION OF THE AMERICAN SOCIETY OF EXPERIMENTAL BIOLOGY','FASEB')
df = df.replace('FRONTIERS MEDIA','FRONTIERS')
df = df.replace('FRONTIERS MEDIA SA','FRONTIERS')
df = df.replace('FRONTIERS RESEARCH FOUNDATION','FRONTIERS')
df = df.replace('FUTURE MEDICINE LTD','FUTURE MEDICINE')
df = df.replace('HINDAWI PUBLISHING CORPORATION','HINDAWI')
df = df.replace('IMPACT JOURNALS LLC','IMPACT JOURNALS')
df = df.replace('INFORMA HEALTHCARE COMMUNICATIONS','INFORMA HEALTHCARE')
df = df.replace('INTERNATIONAL UNION OF CRYSTALLOGRAPHY (IUCR)','INTERNATIONAL UNION OF CRYSTALLOGRAPHY')
df = df.replace('IOS PRESS','IOS PUBLISHING')
df = df.replace('JOHN WILEY','JOHN WILEY & SONS')
df = df.replace('JOHN WILEY & SONS INC','JOHN WILEY & SONS')
df = df.replace('JOHN WILEY & SONS LTD','JOHN WILEY & SONS')
df = df.replace('JOHN WILEY & SONS, INC.','JOHN WILEY & SONS')
df = df.replace('JOHN WILEY AND SONS LTD','JOHN WILEY & SONS')
df = df.replace('LANDES BIOSCIENCES','LANDES BIOSCIENCE')
df = df.replace('MARY ANN LIEBERT INC','MARY ANN LIEBERT')
df = df.replace('MARY ANN LIEBERT, INC. PUBLISHERS','MARY ANN LIEBERT')
df = df.replace('MIT PRESS OPEN ACCESS','MIT PRESS')
df = df.replace('MY JOVE CORPORATION','MY JOVE CORP')
df = df.replace('MYJOVE CORPORATION','MY JOVE CORP')
df = df.replace('NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA','NATIONAL ACADEMY OF SCIENCES')
df = df.replace('NATIONAL ACADEMY OF SCIENCES USA','NATIONAL ACADEMY OF SCIENCES')
df = df.replace('NATIONAL ACADEMY OF SCIENCES, USA','NATIONAL ACADEMY OF SCIENCES')
df = df.replace('NATURE PG','NATURE')
df = df.replace('NATURE PUBLISHING','NATURE')
df = df.replace('NATURE PUBLISHING GROUP LTD','NATURE')
df = df.replace('NATURE PUBLISHING GROUP','NATURE')
df = df.replace('NPG','NATURE')
df = df.replace('OXFORD JOURNALS (OUP)','OXFORD JOURNALS')
df = df.replace('OXFORD JOURNALS','OUP')
df = df.replace('OXFORD UNIV PRESS','OUP')
df = df.replace('OXFORD UNIVERSITY PRESS','OUP')
df = df.replace('OXFORD UNIVERSITY PRESS (OUP)','OUP')
df = df.replace('OXFORD UNIVERSITY PRESS','OUP')
df = df.replace('OXFORD UNIVESITY PRESS','OUP')
df = df.replace('PLOS (PUBLIC LIBRARY OF SCIENCE)','PLOS')
df = df.replace('PLOS PUBLIC LIBRARY OF SCIENCE','PLOS')
df = df.replace('PNAS AUTHOR PUBLICATION','PNAS')
df = df.replace('PMAS','PNAS')
df = df.replace('PORTLAND PRESS LTD','PORTLAND PRESS')
df = df.replace('PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES (PNAS)','PNAS')
df = df.replace('PUBMED CENTRAL','PUBMED')
df = df.replace('ROYAL SOCIETY FOR CHEMISTRY','RSC')
df = df.replace('ROYAL SOCIETY OF CHEMISTRY','RSC')
df = df.replace('RSC PUBLISHING','RSC')

# %%
#match all publisher names (S-Z)

df = df.replace('SAGE PUBLICATIONS','SAGE')
df = df.replace('SAGE PUBLICATIONS INC','SAGE')
df = df.replace('SAGE PUBLICATIONS LTD','SAGE')
df = df.replace('SAGE PUBLISHERS','SAGE')
df = df.replace('SAGE PUBLISHING','SAGE')
df = df.replace('SOCIETY FOR GENERMAL MICROBIOLOGY','SOCIETY FOR GENERAL MICROBIOLOGY')
df = df.replace('SOCIETY OF GENERAL MICROBIOLOGY','SOCIETY FOR GENERAL MICROBIOLOGY')
df = df.replace('SOCIETY FOR NEUROSCIENCES','SOCIETY FOR NEUROSCIENCE')
df = df.replace('SOCIETY OF NEURO SCIENCES','SOCIETY FOR NEUROSCIENCE')
df = df.replace('SOCIETY OF NEUROSCIENCE','SOCIETY FOR NEUROSCIENCE')
df = df.replace('SPRINGER - VERLAG GMBH','SPRINGER')
df = df.replace('SPRINGER SCIENCE + BUSINESS MEDIA','SPRINGER')
df = df.replace('SPRINGER VERLAG','SPRINGER')
df = df.replace('SPRINGER-VERLAG GMBH','SPRINGER')
df = df.replace('SPRINGER-VERLAG GMBH & CI','SPRINGER')
df = df.replace('SPRINGER-VERLAG GMBH, HEIDELBERGER PLATZ 3, D-14197 BERLIN','SPRINGER')
df = df.replace('T&F','TAYLOR & FRANCIS')
df = df.replace('TAYLOR & FRANCIS JOURNALS','TAYLOR & FRANCIS')
df = df.replace('TAYLOR AND FRANCIS','TAYLOR & FRANCIS')
df = df.replace('THE AMERICAN PHYSIOLOGICAL SOCIETY','AMERICAN PHYSIOLOGICAL SOCIETY')
df = df.replace('THE AMERICAN SOCIETY FOR BIOCHEMISTRY AND MOLECULAR BIOLOGY','ASBMB')
df = df.replace('THE AMERICAN SOCIETY FOR BIOCHEMISTRY AND MOLECULAR BIOLOGY, INC','ASBMB')
df = df.replace('THE COMPANY OF BIOLGISTS','COMPANY OF BIOLOGISTS')
df = df.replace('THE COMPANY OF BIOLOGISTS','COMPANY OF BIOLOGISTS')
df = df.replace('THE COMPANY OF BIOLOGISTS LTD','COMPANY OF BIOLOGISTS')
df = df.replace('THE ENDOCRINE SOCETY','ENDOCRINE SOCIETY')
df = df.replace('THE ENDOCRINE SOCIETY','ENDOCRINE SOCIETY')
df = df.replace('THE ENDROCRINE SOCIETY','ENDOCRINE SOCIETY')
df = df.replace('THE JOURNAL OF VISUALIZED EXPERIMENTS','JOURNAL OF VISUALIZED EXPERIMENTS')
df = df.replace('THE ROYAL COLLEGE OF PSYCHIATRISTS','ROYAL COLLEGE OF PSYCHIATRISTS')
df = df.replace('THE ROYAL SOCIETY','ROYAL SOCIETY')
df = df.replace('THE SHERIDAN PRESS','SHERIDAN PRESS')
df = df.replace('WILEY','JOHN WILEY & SONS')
df = df.replace('WILEY & SON','JOHN WILEY & SONS')
df = df.replace('WILEY BLACKWELL','JOHN WILEY & SONS')
df = df.replace('WILEY ONLINE LIBRARY','JOHN WILEY & SONS')
df = df.replace('WILEY SUBSCRIPTION SERVICES','JOHN WILEY & SONS')
df = df.replace('WILEY SUBSCRIPTION SERVICES  INC.','JOHN WILEY & SONS')
df = df.replace('WILEY SUBSCRIPTION SERVICES INC','JOHN WILEY & SONS')
df = df.replace('WILEY SUBSCRIPTION SERVIICES INC','JOHN WILEY & SONS')
df = df.replace('WILEY VCH','JOHN WILEY & SONS')
df = df.replace('WILEY/BLACKWELL','JOHN WILEY & SONS')
df = df.replace('WILEY-BLACKWELL, JOHN WILEY & SONS','JOHN WILEY & SONS')
df = df.replace('WILEY-VCH','JOHN WILEY & SONS')
df = df.replace('WLIEY-BLACKWELL','JOHN WILEY & SONS')
df = df.replace('JOHN WILEY AND SONS','JOHN WILEY & SONS')
df = df.replace('WOLTERS KLUWER HEALTH','WOLTERS KLUWER')
df = df.replace('WOLTERS KLUWER N.V./LIPPINOTT','WOLTERS KLUWER')
df = df.replace('WOLTERS KLUWERS','WOLTERS KLUWER')

# %%
#number of journals from each publisher

df.groupby(['Publisher']).size().sort_values(ascending=False)
# Out:
# Publisher
# ELSEVIER                                                                             408
# PUBLIC LIBRARY OF SCIENCE                                                            278
# JOHN WILEY & SONS                                                                    213
# OUP                                                                                  167
# BMC                                                                                   95
# SPRINGER                                                                              93
# NATURE                                                                                81
# ASBMB                                                                                 74
# BMJ                                                                                   58
# WILEY-BLACKWELL                                                                       56
# ...

# %% [markdown]
# Calculate the mean, median, and standard deviation of the open-access cost per article for each journal.
#
# ANSWER for top 5 in £ (in chart below):

# %%
#mean cost of each publisher

df.groupby('Publisher')['Cost'].mean().sort_index()
# Out:
# Publisher
# ACS                                                                                    1262.137333
# AGA INSTITUTE                                                                           238.080000
# AMERICAN ASSOCIATION OF IMMUNOLOGISTS                                                  2571.540000
# AMERICAN COLLEGE OF CHEST PHYSICIANS                                                   2383.940000
# AMERICAN PHYSIOLOGICAL SOCIETY                                                         1353.926250
# AMERICAN PSYCHIATRIC ASSOCIATION                                                       2350.875000
# AMERICAN PSYCHOLOGICAL ASSOCIATION                                                     2905.475000
# AMERICAN PUBLIC HEALTH ASSOCIATION                                                     1422.250000
# AMERICAN SOCIETY FOR INVESTIGATIVE PATHOLOGY                                            995.310000
# ...

# %%
#median cost of each publisher

df.groupby('Publisher')['Cost'].median().sort_index()
# Out:
# Publisher
# ACS                                                                                    1277.480
# AGA INSTITUTE                                                                           238.080
# AMERICAN ASSOCIATION OF IMMUNOLOGISTS                                                  2571.540
# AMERICAN COLLEGE OF CHEST PHYSICIANS                                                   2383.940
# AMERICAN PHYSIOLOGICAL SOCIETY                                                         1302.800
# AMERICAN PSYCHIATRIC ASSOCIATION                                                       2350.875
# AMERICAN PSYCHOLOGICAL ASSOCIATION                                                     2997.520
# AMERICAN PUBLIC HEALTH ASSOCIATION                                                     1422.250
# AMERICAN SOCIETY FOR INVESTIGATIVE PATHOLOGY                                            995.310
# AMERICAN SOCIETY FOR NUTRITION                                                           45.940
# ...

# %%
#standard deviation of cost for each publisher (NaN due to only 1 )


df.groupby('Publisher')['Cost'].std().sort_index()
# Out:
# Publisher
# ACS                                                                                     628.206705
# AGA INSTITUTE                                                                                  NaN
# AMERICAN ASSOCIATION OF IMMUNOLOGISTS                                                   758.782145
# AMERICAN COLLEGE OF CHEST PHYSICIANS                                                           NaN
# AMERICAN PHYSIOLOGICAL SOCIETY                                                          112.067341
# AMERICAN PSYCHIATRIC ASSOCIATION                                                          1.209153
# AMERICAN PSYCHOLOGICAL ASSOCIATION                                                      275.989046
# AMERICAN PUBLIC HEALTH ASSOCIATION                                                             NaN
# AMERICAN SOCIETY FOR INVESTIGATIVE PATHOLOGY                                                   NaN
# ...
